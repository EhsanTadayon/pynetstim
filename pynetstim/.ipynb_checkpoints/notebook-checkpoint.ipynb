# %% [markdown]
# # developing and testing pynetstim

# %%
import nibabel as nib
import numpy as np

from surfer import Brain
from mayavi import mlab
# %gui qt
from coordinates import Coords,Surf, FreesurferSurf, FreesurferCoords
from targets import Targets
from project import StimProject
import matplotlib.pyplot as plt
# %matplotlib inline
#import seaborn as sns
#sns.set_context('notebook')
#sns.set_style('ticks')
from pymisc.plotting import clean_plot
from collections import defaultdict
from plotting import plotting_points
from tms_simulation import Simnibs
# Out:
# plotting.py:9: DeprecationWarning: Python2 support is deprecated and will be removed in a future release. Consider switching to Python3.
#   from nilearn.plotting import plot_anat

# %% [markdown]
# ## Visualization

# %%
subject = 'Broad_63_LG'
freesurfer_dir = '/Users/stadayon/Dropbox/projects/broad/data/freesurfer/subjects'
simnibs_dir = '/Users/stadayon/Dropbox/projects/broad/data/mri2mesh/{subject}'.format(subject=subject)
simnibs_simulation_dir = '/Users/stadayon/Dropbox/projects/broad/data/simnibs_simulations/{subject}'.format(subject=subject)
project_dir = '/Users/stadayon/Desktop/pynetstim_test/'
brainsight_file = '/Users/stadayon/Dropbox/projects/broad/data/sessions_data_raw/{subject}_sessions_data.txt'.format(subject=subject)


project = StimProject(subject,freesurfer_dir = freesurfer_dir,project_dir= project_dir,brainsight_file = brainsight_file, overwrite='all')
project.summary(plot_pulses=False)
# Out:
# Target
# Sample
# Planned
# Session

# %%
targets = project.brainsight_targets
samples = project.brainsight_samples

# %%
plotting_points(targets,'both','pial','pial',show_roi=True,show_name=True,scale_factor=.5)

# %%
s = Simnibs(subject,simnibs_dir,simnibs_simulation_dir)

# %%
targets.name
# Out:
# array(['IDEF', 'IDAN', 'CDAN', 'LDLPFC', 'CDEF', 'RDLPFC', 'R_Occ',
#        'L_IPL', 'Mono_V1_1', 'Mono_V1_2', 'Mono_V1_3', 'Mono_V1_4',
#        'MONO_V2_1', 'MONO_V3_1', 'MONO_V3_2', 'MONO_V3_3', 'MONO_V3_4',
#        'Mono_v3_5', 'MONO_V3_6', 'MONO_V3_7', 'MONO_V3_8', 'MONO_V4_1',
#        'MONO_V4_2', 'MONO_V4_3', 'Mono_V4_3', 'Mono_V4_4', 'MONO_V5_1',
#        'MONO_V5_2', 'MONO_V6_1'], dtype=object)

# %%
targets_inds = []
targets_inds.append(np.where(targets.name=='Mono_V1_4')[0][0])
targets_inds.append(np.where(targets.name=='LDLPFC')[0][0])

# %%
targets = Targets(targets.coordinates['ras_coord'][targets_inds,:], subject, freesurfer_dir , direction=targets.direction[targets_inds,:],
                  name =np.array(['M1','L_DLPFC']))

# %%
s.add_targets(targets,'targets_M1_LDLPFC.csv',t12simnibs=True,project2skin=True)
# Out:
# 181113-11:18:37,5 nipype.workflow INFO:
# 	 Workflow T1_to_simnibs_registration settings: ['check', 'execution', 'logging', 'monitoring']
# 181113-11:18:37,13 nipype.workflow INFO:
# 	 Running serially.
# 181113-11:18:37,17 nipype.workflow INFO:
# 	 [Node] Setting-up "T1_to_simnibs_registration.flirt" in "/Users/stadayon/Dropbox/projects/broad/data/simnibs_simulations/Broad_63_LG/T1_to_simnibs_registration/flirt".
# 181113-11:18:37,32 nipype.workflow INFO:
# 	 [Node] Running "flirt" ("nipype.interfaces.fsl.preprocess.FLIRT"), a CommandLine Interface with command:
# flirt -in /Users/stadayon/Dropbox/projects/broad/data/mri2mesh/Broad_63_LG/m2m_Broad_63_LG/T1fs.nii.gz -ref /Users/stadayon/Dropbox/projects/broad/data/mri2mesh/Broad_63_LG/m2m_Broad_63_LG/T1fs_conform.nii.gz -out T1_in_Simnibs.nii.gz -omat T12Simnibs.mat -searchrx -180 180 -searchry -180 180 -searchrz -180 180
# [ simnibs ]WARNING: /Users/stadayon/anaconda2/envs/pynetstim/lib/python2.7/site-packages/nipype/pipeline/engine/utils.py:307: DeprecationWarning: use "HasTraits.trait_set" instead
#   result.outputs.set(**modify_paths(tosave, relative=True, basedir=cwd))
# 181113-11:20:07,481 nipype.workflow INFO:
# 	 [Node] Finished "T1_to_simnibs_registration.flirt".
# 181113-11:20:07,688 nipype.interface INFO:
# 	 stdout 2018-11-13T11:20:07.688643:Coordinates in Destination volume (in mm)
# 181113-11:20:07,692 nipype.interface INFO:
# 	 stdout 2018-11-13T11:20:07.692853:-40.1482  -3.89581  65.475
# 181113-11:20:07,694 nipype.interface INFO:
# 	 stdout 2018-11-13T11:20:07.692853:-35.248  28.3136  36.8101
# 181113-11:20:07,695 nipype.interface INFO:
# 	 stdout 2018-11-13T11:20:07.692853:-35.248  28.3136  36.8101

# %%
s.run_simnibs('targets_M1_LDLPFC2',didt=120e6)
# Out:
# [ simnibs ]INFO: Could not find the dti tensor file in the standard location: /Users/stadayon/Dropbox/projects/broad/data/mri2mesh/Broad_63_LG/d2c_Broad_63_LG/dti_results_T1space/DTI_conf_tensor.nii.gz
# [ simnibs ]INFO: Head Mesh: /Users/stadayon/Dropbox/projects/broad/data/mri2mesh/Broad_63_LG/Broad_63_LG.msh
# [ simnibs ]INFO: Subject Path: /Users/stadayon/Dropbox/projects/broad/data/mri2mesh/Broad_63_LG/m2m_Broad_63_LG
# [ simnibs ]INFO: Simulation Folder: /Users/stadayon/Dropbox/projects/broad/data/simnibs_simulations/Broad_63_LG/simnibs_simulations/targets_M1_LDLPFC2
# [ simnibs ]INFO: Running simulations in the directory: /Users/stadayon/Dropbox/projects/broad/data/simnibs_simulations/Broad_63_LG/simnibs_simulations/targets_M1_LDLPFC2
# [ simnibs ]INFO: Running Poslist Number: 1
# [ simnibs ]INFO: Began to run TMS simulations
# [ simnibs ]INFO: Using coil: /Users/stadayon/simnibs_2.1.1/ccd-files/MagVenture_MC_B70.ccd
# [ simnibs ]INFO: Using isotropic conductivities
# 0
# [ simnibs ]INFO: Running TMS Position 0
# [ simnibs ]INFO: Coil Position Matrix: [[0.5446259999999999, 0.665, -0.511, -40.3830032349], [-0.6939660000000001, 0.699, 0.171, -4.13698196411], [0.470904, 0.261, 0.843, 63.3097877502], [0.0, 0.0, 0.0, 1.0]]
# dIdt: 120000000.0
#
# [ simnibs ]INFO: Executing:
# /Users/stadayon/simnibs_2.1.1/bin/getdp /Users/stadayon/Dropbox/projects/broad/data/simnibs_simulations/Broad_63_LG/simnibs_simulations/targets_M1_LDLPFC2/Broad_63_LG_TMS_1-0001_MagVenture_MC_B70.pro -solve QS -msh /Users/stadayon/Dropbox/projects/broad/data/simnibs_simulations/Broad_63_LG/simnibs_simulations/targets_M1_LDLPFC2/tmpiDnV6f.msh -ksp_type cg -ksp_rtol 1e-10 -pc_type icc -pc_factor_levels 2 -v2 -bin
# [ simnibs ]INFO: Info    : Running '/Users/stadayon/simnibs_2.1.1/bin/getdp /Users/stadayon/Dropbox/projects/broad/data/simnibs_simulations/Broad_63_LG/simnibs_simulations/targets_M1_LDLPFC2/Broad_63_LG_TMS_1-0001_MagVenture_MC_B70.pro -solve QS -msh /Users/stadayon/Dropbox/projects/broad/data/simnibs_simulations/Broad_63_LG/simnibs_simulations/targets_M1_LDLPFC2/tmpiDnV6f.msh -ksp_type cg -ksp_rtol 1e-10 -pc_type icc -pc_factor_levels 2 -v2 -bin' [GetDP 2.11.3, 1 node, max. 1 thread]
# [ simnibs ]INFO: Info    : Started (Tue Nov 13 11:23:31 2018, Wall = 0.092077s, CPU = 0.170327s, Mem = 7.08594Mb)
# [ simnibs ]INFO: Info    : Initializing Gmsh
# [ simnibs ]INFO: Info    : Loading problem definition '/Users/stadayon/Dropbox/projects/broad/data/simnibs_simulations/Broad_63_LG/simnibs_simulations/targets_M1_LDLPFC2/Broad_63_LG_TMS_1-0001_MagVenture_MC_B70.pro'
# [ simnibs ]INFO: Info    : Selected Resolution 'QS'
# [ simnibs ]INFO: Info    : Loading Geometric data '/Users/stadayon/Dropbox/projects/broad/data/simnibs_simulations/Broad_63_LG/simnibs_simulations/targets_M1_LDLPFC2/tmpiDnV6f.msh'
# [ simnibs ]INFO: Info    : Mesh is in binary format
# [ simnibs ]INFO: Info    : System 'QS_dAdt' : Real
# [ simnibs ]INFO: P r e - P r o c e s s i n g . . .
# [ simnibs ]INFO: Info    : Treatment Formulation 'QS_Formulation'
# Info    : System 1/1: 653426 Dofs
# [ simnibs ]INFO: Info    : (Wall = 14.8321s, CPU = 13.7962s, Mem = 506.848Mb)
# [ simnibs ]INFO: E n d   P r e - P r o c e s s i n g
# [ simnibs ]INFO: P r o c e s s i n g . . .
# [ simnibs ]INFO: Info    : GmshRead[/Users/stadayon/Dropbox/projects/broad/data/simnibs_simulations/Broad_63_LG/simnibs_simulations/targets_M1_LDLPFC2/Broad_63_LG_TMS_1_cond.msh] -> View[1]
# [ simnibs ]INFO: Info    : No current model available: creating one
# [ simnibs ]INFO: Info    : Reading '/Users/stadayon/Dropbox/projects/broad/data/simnibs_simulations/Broad_63_LG/simnibs_simulations/targets_M1_LDLPFC2/Broad_63_LG_TMS_1_cond.msh'...
# [ simnibs ]INFO: Info    : 653426 vertices
# [ simnibs ]INFO: Info    : Reading nodes
# [ simnibs ]INFO: Info    : Reading nodes
# [ simnibs ]INFO: Info    : Reading nodes
# [ simnibs ]INFO: Info    : Reading nodes
# [ simnibs ]INFO: Info    : Reading nodes
# [ simnibs ]INFO: Info    : Reading nodes
# [ simnibs ]INFO: Info    : 4544281 elements
# [ simnibs ]INFO: Info    : Reading elements
# [ simnibs ]INFO: Info    : Reading elements
# [ simnibs ]INFO: Info    : Reading elements
# [ simnibs ]INFO: Info    : Reading elements
# [ simnibs ]INFO: Info    : Reading elements
# [ simnibs ]INFO: Info    : Reading elements
# [ simnibs ]INFO: Info    : Reading data
# [ simnibs ]INFO: Info    : Reading data
# [ simnibs ]INFO: Info    : Reading data
# [ simnibs ]INFO: Info    : Reading data
# [ simnibs ]INFO: Info    : Reading data
# [ simnibs ]INFO: Info    : Reading data
# [ simnibs ]INFO: Info    : Done reading '/Users/stadayon/Dropbox/projects/broad/data/simnibs_simulations/Broad_63_LG/simnibs_simulations/targets_M1_LDLPFC2/Broad_63_LG_TMS_1_cond.msh'
# [ simnibs ]INFO: Info    : GmshRead[/Users/stadayon/Dropbox/projects/broad/data/simnibs_simulations/Broad_63_LG/simnibs_simulations/targets_M1_LDLPFC2/Broad_63_LG_TMS_1-0001_MagVenture_MC_B70_dadt.msh] -> View[2]
# [ simnibs ]INFO: Info    : Reading '/Users/stadayon/Dropbox/projects/broad/data/simnibs_simulations/Broad_63_LG/simnibs_simulations/targets_M1_LDLPFC2/Broad_63_LG_TMS_1-0001_MagVenture_MC_B70_dadt.msh'...
# [ simnibs ]INFO: Info    : 653426 vertices
# [ simnibs ]INFO: Info    : Reading nodes
# [ simnibs ]INFO: Info    : Reading nodes
# [ simnibs ]INFO: Info    : Reading nodes
# [ simnibs ]INFO: Info    : Reading nodes
# [ simnibs ]INFO: Info    : Reading nodes
# [ simnibs ]INFO: Info    : Reading nodes
# [ simnibs ]INFO: Info    : 4544281 elements
# [ simnibs ]INFO: Info    : Reading elements
# [ simnibs ]INFO: Info    : Reading elements
# [ simnibs ]INFO: Info    : Reading elements
# [ simnibs ]INFO: Info    : Reading elements
# [ simnibs ]INFO: Info    : Reading elements
# [ simnibs ]INFO: Info    : Reading elements
# [ simnibs ]INFO: Info    : Reading data
# [ simnibs ]INFO: Info    : Reading data
# [ simnibs ]INFO: Info    : Reading data
# [ simnibs ]INFO: Info    : Reading data
# [ simnibs ]INFO: Info    : Reading data
# [ simnibs ]INFO: Info    : Reading data
# [ simnibs ]INFO: Info    : Done reading '/Users/stadayon/Dropbox/projects/broad/data/simnibs_simulations/Broad_63_LG/simnibs_simulations/targets_M1_LDLPFC2/Broad_63_LG_TMS_1-0001_MagVenture_MC_B70_dadt.msh'
# [ simnibs ]INFO: Info    : Generate[QS_dAdt]
# Info    : Solve[QS_dAdt]
# [ simnibs ]INFO: Info    : N: 653426 - cg icc (null)
# [ simnibs ]INFO: Info    :   0 KSP Residual norm 8.362083180257e+01
# [ simnibs ]INFO: Info    :   1 KSP Residual norm 2.769827133730e+01
# [ simnibs ]INFO: Info    :   2 KSP Residual norm 2.646724287769e+01
# [ simnibs ]INFO: Info    :   3 KSP Residual norm 2.436671373429e+01
# [ simnibs ]INFO: Info    :   4 KSP Residual norm 2.306023674210e+01
# [ simnibs ]INFO: Info    :   5 KSP Residual norm 2.353032662060e+01
# [ simnibs ]INFO: Info    :   6 KSP Residual norm 2.197950771980e+01
# [ simnibs ]INFO: Info    :   7 KSP Residual norm 1.977751433375e+01
# [ simnibs ]INFO: Info    :   8 KSP Residual norm 1.803737322445e+01
# [ simnibs ]INFO: Info    :   9 KSP Residual norm 1.526971540192e+01
# [ simnibs ]INFO: Info    :  10 KSP Residual norm 1.382595002245e+01
# [ simnibs ]INFO: Info    :  11 KSP Residual norm 1.274251505210e+01
# [ simnibs ]INFO: Info    :  12 KSP Residual norm 1.157822516616e+01
# [ simnibs ]INFO: Info    :  13 KSP Residual norm 1.079268814443e+01
# [ simnibs ]INFO: Info    :  14 KSP Residual norm 9.872464594161e+00
# [ simnibs ]INFO: Info    :  15 KSP Residual norm 9.172450707502e+00
# [ simnibs ]INFO: Info    :  16 KSP Residual norm 8.354186173695e+00
# [ simnibs ]INFO: Info    :  17 KSP Residual norm 7.367903958148e+00
# [ simnibs ]INFO: Info    :  18 KSP Residual norm 6.432926454317e+00
# [ simnibs ]INFO: Info    :  19 KSP Residual norm 5.677456546982e+00
# [ simnibs ]INFO: Info    :  20 KSP Residual norm 4.825679001833e+00
# [ simnibs ]INFO: Info    :  21 KSP Residual norm 4.113594741778e+00
# [ simnibs ]INFO: Info    :  22 KSP Residual norm 3.407610015314e+00
# [ simnibs ]INFO: Info    :  23 KSP Residual norm 2.888914217255e+00
# [ simnibs ]INFO: Info    :  24 KSP Residual norm 2.529381239528e+00
# [ simnibs ]INFO: Info    :  25 KSP Residual norm 2.155418110714e+00
# [ simnibs ]INFO: Info    :  26 KSP Residual norm 1.849565245700e+00
# [ simnibs ]INFO: Info    :  27 KSP Residual norm 1.571553605771e+00
# [ simnibs ]INFO: Info    :  28 KSP Residual norm 1.345269389773e+00
# [ simnibs ]INFO: Info    :  29 KSP Residual norm 1.189713091283e+00
# [ simnibs ]INFO: Info    :  30 KSP Residual norm 1.079216099113e+00
# [ simnibs ]INFO: Info    :  31 KSP Residual norm 9.882649587437e-01
# [ simnibs ]INFO: Info    :  32 KSP Residual norm 9.279682473916e-01
# [ simnibs ]INFO: Info    :  33 KSP Residual norm 8.794410014470e-01
# [ simnibs ]INFO: Info    :  34 KSP Residual norm 8.438242004013e-01
# [ simnibs ]INFO: Info    :  35 KSP Residual norm 7.476622065979e-01
# [ simnibs ]INFO: Info    :  36 KSP Residual norm 6.736771463145e-01
# [ simnibs ]INFO: Info    :  37 KSP Residual norm 6.169081716674e-01
# [ simnibs ]INFO: Info    :  38 KSP Residual norm 5.710499937003e-01
# [ simnibs ]INFO: Info    :  39 KSP Residual norm 5.211129637976e-01
# [ simnibs ]INFO: Info    :  40 KSP Residual norm 4.597541804005e-01
# [ simnibs ]INFO: Info    :  41 KSP Residual norm 3.910851826100e-01
# [ simnibs ]INFO: Info    :  42 KSP Residual norm 3.369215064632e-01
# [ simnibs ]INFO: Info    :  43 KSP Residual norm 2.866045767747e-01
# [ simnibs ]INFO: Info    :  44 KSP Residual norm 2.504468601876e-01
# [ simnibs ]INFO: Info    :  45 KSP Residual norm 2.178491670988e-01
# [ simnibs ]INFO: Info    :  46 KSP Residual norm 1.783873692569e-01
# [ simnibs ]INFO: Info    :  47 KSP Residual norm 1.433265921108e-01
# [ simnibs ]INFO: Info    :  48 KSP Residual norm 1.174195481445e-01
# [ simnibs ]INFO: Info    :  49 KSP Residual norm 9.664291324035e-02
# [ simnibs ]INFO: Info    :  50 KSP Residual norm 7.925325611340e-02
# [ simnibs ]INFO: Info    :  51 KSP Residual norm 6.533739806267e-02
# [ simnibs ]INFO: Info    :  52 KSP Residual norm 5.283311638429e-02
# [ simnibs ]INFO: Info    :  53 KSP Residual norm 4.374099362917e-02
# [ simnibs ]INFO: Info    :  54 KSP Residual norm 3.647983366839e-02
# [ simnibs ]INFO: Info    :  55 KSP Residual norm 3.022769619574e-02
# [ simnibs ]INFO: Info    :  56 KSP Residual norm 2.480935568120e-02
# [ simnibs ]INFO: Info    :  57 KSP Residual norm 2.056325901038e-02
# [ simnibs ]INFO: Info    :  58 KSP Residual norm 1.753713142724e-02
# [ simnibs ]INFO: Info    :  59 KSP Residual norm 1.497396433114e-02
# [ simnibs ]INFO: Info    :  60 KSP Residual norm 1.308414588915e-02
# [ simnibs ]INFO: Info    :  61 KSP Residual norm 1.168121673960e-02
# [ simnibs ]INFO: Info    :  62 KSP Residual norm 1.082833892639e-02
# [ simnibs ]INFO: Info    :  63 KSP Residual norm 1.018660443130e-02
# [ simnibs ]INFO: Info    :  64 KSP Residual norm 9.420078296577e-03
# [ simnibs ]INFO: Info    :  65 KSP Residual norm 8.366954943401e-03
# [ simnibs ]INFO: Info    :  66 KSP Residual norm 7.492996021927e-03
# [ simnibs ]INFO: Info    :  67 KSP Residual norm 6.497167134119e-03
# [ simnibs ]INFO: Info    :  68 KSP Residual norm 5.675093783495e-03
# [ simnibs ]INFO: Info    :  69 KSP Residual norm 5.117962394201e-03
# [ simnibs ]INFO: Info    :  70 KSP Residual norm 4.549038771335e-03
# [ simnibs ]INFO: Info    :  71 KSP Residual norm 4.159153108695e-03
# [ simnibs ]INFO: Info    :  72 KSP Residual norm 3.690713179071e-03
# [ simnibs ]INFO: Info    :  73 KSP Residual norm 3.215039744305e-03
# [ simnibs ]INFO: Info    :  74 KSP Residual norm 2.929215567270e-03
# [ simnibs ]INFO: Info    :  75 KSP Residual norm 2.620372358236e-03
# [ simnibs ]INFO: Info    :  76 KSP Residual norm 2.195876117580e-03
# [ simnibs ]INFO: Info    :  77 KSP Residual norm 1.862319823202e-03
# [ simnibs ]INFO: Info    :  78 KSP Residual norm 1.574816341822e-03
# [ simnibs ]INFO: Info    :  79 KSP Residual norm 1.280613779087e-03
# [ simnibs ]INFO: Info    :  80 KSP Residual norm 1.058159524566e-03
# [ simnibs ]INFO: Info    :  81 KSP Residual norm 8.580639037773e-04
# [ simnibs ]INFO: Info    :  82 KSP Residual norm 6.808642222759e-04
# [ simnibs ]INFO: Info    :  83 KSP Residual norm 5.544621114876e-04
# [ simnibs ]INFO: Info    :  84 KSP Residual norm 4.467955803005e-04
# [ simnibs ]INFO: Info    :  85 KSP Residual norm 3.691634319491e-04
# [ simnibs ]INFO: Info    :  86 KSP Residual norm 2.967666993494e-04
# [ simnibs ]INFO: Info    :  87 KSP Residual norm 2.395895874348e-04
# [ simnibs ]INFO: Info    :  88 KSP Residual norm 1.910791449386e-04
# [ simnibs ]INFO: Info    :  89 KSP Residual norm 1.489958001538e-04
# [ simnibs ]INFO: Info    :  90 KSP Residual norm 1.153008879630e-04
# [ simnibs ]INFO: Info    :  91 KSP Residual norm 9.202102363557e-05
# [ simnibs ]INFO: Info    :  92 KSP Residual norm 7.787245350916e-05
# [ simnibs ]INFO: Info    :  93 KSP Residual norm 6.857901247423e-05
# [ simnibs ]INFO: Info    :  94 KSP Residual norm 5.917176633168e-05
# [ simnibs ]INFO: Info    :  95 KSP Residual norm 4.725696488784e-05
# [ simnibs ]INFO: Info    :  96 KSP Residual norm 3.785204327369e-05
# [ simnibs ]INFO: Info    :  97 KSP Residual norm 3.165365351747e-05
# [ simnibs ]INFO: Info    :  98 KSP Residual norm 2.588799644492e-05
# [ simnibs ]INFO: Info    :  99 KSP Residual norm 2.133718112151e-05
# [ simnibs ]INFO: Info    : 100 KSP Residual norm 1.784950976261e-05
# [ simnibs ]INFO: Info    : 101 KSP Residual norm 1.455278443142e-05
# [ simnibs ]INFO: Info    : 102 KSP Residual norm 1.191657150992e-05
# [ simnibs ]INFO: Info    : 103 KSP Residual norm 1.031451175853e-05
# [ simnibs ]INFO: Info    : 104 KSP Residual norm 8.816763720841e-06
# [ simnibs ]INFO: Info    : 105 KSP Residual norm 7.564215945274e-06
# [ simnibs ]INFO: Info    : 106 KSP Residual norm 6.367171386377e-06
# [ simnibs ]INFO: Info    : 107 KSP Residual norm 5.098493863016e-06
# [ simnibs ]INFO: Info    : 108 KSP Residual norm 3.976917059752e-06
# [ simnibs ]INFO: Info    : 109 KSP Residual norm 3.235397433799e-06
# [ simnibs ]INFO: Info    : 110 KSP Residual norm 2.733938417350e-06
# [ simnibs ]INFO: Info    : 111 KSP Residual norm 2.213736264919e-06
# [ simnibs ]INFO: Info    : 112 KSP Residual norm 1.810693506280e-06
# [ simnibs ]INFO: Info    : 113 KSP Residual norm 1.534148339692e-06
# [ simnibs ]INFO: Info    : 114 KSP Residual norm 1.300467079845e-06
# [ simnibs ]INFO: Info    : 115 KSP Residual norm 1.053022783973e-06
# [ simnibs ]INFO: Info    : 116 KSP Residual norm 8.434798317045e-07
# [ simnibs ]INFO: Info    : 117 KSP Residual norm 6.699259097111e-07
# [ simnibs ]INFO: Info    : 118 KSP Residual norm 5.562614653034e-07
# [ simnibs ]INFO: Info    : 119 KSP Residual norm 4.897811263104e-07
# [ simnibs ]INFO: Info    : 120 KSP Residual norm 4.158366894116e-07
# [ simnibs ]INFO: Info    : 121 KSP Residual norm 3.378810512169e-07
# [ simnibs ]INFO: Info    : 122 KSP Residual norm 2.700675716774e-07
# [ simnibs ]INFO: Info    : 123 KSP Residual norm 2.092974082945e-07
# [ simnibs ]INFO: Info    : 124 KSP Residual norm 1.652734297558e-07
# [ simnibs ]INFO: Info    : 125 KSP Residual norm 1.279951283388e-07
# [ simnibs ]INFO: Info    : 126 KSP Residual norm 1.009362537519e-07
# [ simnibs ]INFO: Info    : 127 KSP Residual norm 8.086553853814e-08
# [ simnibs ]INFO: Info    : 128 KSP Residual norm 6.665101028010e-08
# [ simnibs ]INFO: Info    : 129 KSP Residual norm 5.256128899870e-08
# [ simnibs ]INFO: Info    : 130 KSP Residual norm 4.046082489077e-08
# [ simnibs ]INFO: Info    : 131 KSP Residual norm 3.056535059393e-08
# [ simnibs ]INFO: Info    : 132 KSP Residual norm 2.279737634815e-08
# [ simnibs ]INFO: Info    : 133 KSP Residual norm 1.745371726475e-08
# [ simnibs ]INFO: Info    : 134 KSP Residual norm 1.412258084964e-08
# [ simnibs ]INFO: Info    : 135 KSP Residual norm 1.119180860611e-08
# [ simnibs ]INFO: Info    : 136 KSP Residual norm 8.838825940231e-09
# [ simnibs ]INFO: Info    : 137 KSP Residual norm 6.958737190616e-09
# [ simnibs ]INFO: Info    : 137 iterations
# [ simnibs ]INFO: Info    : SaveSolution[QS_dAdt]
# [ simnibs ]INFO: Info    : (Wall = 317.593s, CPU = 321.962s, Mem = 3996.48Mb)
# [ simnibs ]INFO: E n d   P r o c e s s i n g
# [ simnibs ]INFO: Info    : Stopped (Tue Nov 13 11:28:50 2018, Wall = 319.04s, CPU = 322.914s, Mem = 3996.48Mb)
# [ simnibs ]INFO: Execution finished
# [ simnibs ]WARNING: /Users/stadayon/anaconda2/envs/pynetstim/lib/python2.7/site-packages/simnibs/msh/gmsh_numpy.py:3241: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   cols = np.fromstring(s[0:-1], dtype=np.float)
# 1
# [ simnibs ]INFO: Running TMS Position 1
# [ simnibs ]INFO: Coil Position Matrix: [[0.011499999999999982, 0.815, -0.579, -47.551322937], [-0.8783799999999999, 0.285, 0.383, 34.5525436401], [0.47716, 0.505, 0.719, 46.2069778442], [0.0, 0.0, 0.0, 1.0]]
# dIdt: 120000000.0
#
# [ simnibs ]INFO: Executing:
# /Users/stadayon/simnibs_2.1.1/bin/getdp /Users/stadayon/Dropbox/projects/broad/data/simnibs_simulations/Broad_63_LG/simnibs_simulations/targets_M1_LDLPFC2/Broad_63_LG_TMS_1-0002_MagVenture_MC_B70.pro -solve QS -msh /Users/stadayon/Dropbox/projects/broad/data/simnibs_simulations/Broad_63_LG/simnibs_simulations/targets_M1_LDLPFC2/tmpEa6vUw.msh -ksp_type cg -ksp_rtol 1e-10 -pc_type icc -pc_factor_levels 2 -v2 -bin
# [ simnibs ]INFO: Info    : Running '/Users/stadayon/simnibs_2.1.1/bin/getdp /Users/stadayon/Dropbox/projects/broad/data/simnibs_simulations/Broad_63_LG/simnibs_simulations/targets_M1_LDLPFC2/Broad_63_LG_TMS_1-0002_MagVenture_MC_B70.pro -solve QS -msh /Users/stadayon/Dropbox/projects/broad/data/simnibs_simulations/Broad_63_LG/simnibs_simulations/targets_M1_LDLPFC2/tmpEa6vUw.msh -ksp_type cg -ksp_rtol 1e-10 -pc_type icc -pc_factor_levels 2 -v2 -bin' [GetDP 2.11.3, 1 node, max. 1 thread]
# [ simnibs ]INFO: Info    : Started (Tue Nov 13 11:32:21 2018, Wall = 0.0417621s, CPU = 0.086857s, Mem = 7.11328Mb)
# [ simnibs ]INFO: Info    : Initializing Gmsh
# [ simnibs ]INFO: Info    : Loading problem definition '/Users/stadayon/Dropbox/projects/broad/data/simnibs_simulations/Broad_63_LG/simnibs_simulations/targets_M1_LDLPFC2/Broad_63_LG_TMS_1-0002_MagVenture_MC_B70.pro'
# [ simnibs ]INFO: Info    : Selected Resolution 'QS'
# [ simnibs ]INFO: Info    : Loading Geometric data '/Users/stadayon/Dropbox/projects/broad/data/simnibs_simulations/Broad_63_LG/simnibs_simulations/targets_M1_LDLPFC2/tmpEa6vUw.msh'
# [ simnibs ]INFO: Info    : Mesh is in binary format
# [ simnibs ]INFO: Info    : System 'QS_dAdt' : Real
# [ simnibs ]INFO: P r e - P r o c e s s i n g . . .
# [ simnibs ]INFO: Info    : Treatment Formulation 'QS_Formulation'
# Info    : System 1/1: 653426 Dofs
# [ simnibs ]INFO: Info    : (Wall = 10.7562s, CPU = 10.4703s, Mem = 506.902Mb)
# [ simnibs ]INFO: E n d   P r e - P r o c e s s i n g
# [ simnibs ]INFO: P r o c e s s i n g . . .
# [ simnibs ]INFO: Info    : GmshRead[/Users/stadayon/Dropbox/projects/broad/data/simnibs_simulations/Broad_63_LG/simnibs_simulations/targets_M1_LDLPFC2/Broad_63_LG_TMS_1_cond.msh] -> View[1]
# [ simnibs ]INFO: Info    : No current model available: creating one
# [ simnibs ]INFO: Info    : Reading '/Users/stadayon/Dropbox/projects/broad/data/simnibs_simulations/Broad_63_LG/simnibs_simulations/targets_M1_LDLPFC2/Broad_63_LG_TMS_1_cond.msh'...
# [ simnibs ]INFO: Info    : 653426 vertices
# [ simnibs ]INFO: Info    : Reading nodes
# [ simnibs ]INFO: Info    : Reading nodes
# [ simnibs ]INFO: Info    : Reading nodes
# [ simnibs ]INFO: Info    : Reading nodes
# [ simnibs ]INFO: Info    : Reading nodes
# [ simnibs ]INFO: Info    : Reading nodes
# [ simnibs ]INFO: Info    : 4544281 elements
# [ simnibs ]INFO: Info    : Reading elements
# [ simnibs ]INFO: Info    : Reading elements
# [ simnibs ]INFO: Info    : Reading elements
# [ simnibs ]INFO: Info    : Reading elements
# [ simnibs ]INFO: Info    : Reading elements
# [ simnibs ]INFO: Info    : Reading elements
# [ simnibs ]INFO: Info    : Reading data
# [ simnibs ]INFO: Info    : Reading data
# [ simnibs ]INFO: Info    : Reading data
# [ simnibs ]INFO: Info    : Reading data
# [ simnibs ]INFO: Info    : Reading data
# [ simnibs ]INFO: Info    : Reading data
# [ simnibs ]INFO: Info    : Done reading '/Users/stadayon/Dropbox/projects/broad/data/simnibs_simulations/Broad_63_LG/simnibs_simulations/targets_M1_LDLPFC2/Broad_63_LG_TMS_1_cond.msh'
# [ simnibs ]INFO: Info    : GmshRead[/Users/stadayon/Dropbox/projects/broad/data/simnibs_simulations/Broad_63_LG/simnibs_simulations/targets_M1_LDLPFC2/Broad_63_LG_TMS_1-0002_MagVenture_MC_B70_dadt.msh] -> View[2]
# [ simnibs ]INFO: Info    : Reading '/Users/stadayon/Dropbox/projects/broad/data/simnibs_simulations/Broad_63_LG/simnibs_simulations/targets_M1_LDLPFC2/Broad_63_LG_TMS_1-0002_MagVenture_MC_B70_dadt.msh'...
# [ simnibs ]INFO: Info    : 653426 vertices
# [ simnibs ]INFO: Info    : Reading nodes
# [ simnibs ]INFO: Info    : Reading nodes
# [ simnibs ]INFO: Info    : Reading nodes
# [ simnibs ]INFO: Info    : Reading nodes
# [ simnibs ]INFO: Info    : Reading nodes
# [ simnibs ]INFO: Info    : Reading nodes
# [ simnibs ]INFO: Info    : 4544281 elements
# [ simnibs ]INFO: Info    : Reading elements
# [ simnibs ]INFO: Info    : Reading elements
# [ simnibs ]INFO: Info    : Reading elements
# [ simnibs ]INFO: Info    : Reading elements
# [ simnibs ]INFO: Info    : Reading elements
# [ simnibs ]INFO: Info    : Reading elements
# [ simnibs ]INFO: Info    : Reading data
# [ simnibs ]INFO: Info    : Reading data
# [ simnibs ]INFO: Info    : Reading data
# [ simnibs ]INFO: Info    : Reading data
# [ simnibs ]INFO: Info    : Reading data
# [ simnibs ]INFO: Info    : Reading data
# [ simnibs ]INFO: Info    : Done reading '/Users/stadayon/Dropbox/projects/broad/data/simnibs_simulations/Broad_63_LG/simnibs_simulations/targets_M1_LDLPFC2/Broad_63_LG_TMS_1-0002_MagVenture_MC_B70_dadt.msh'
# [ simnibs ]INFO: Info    : Generate[QS_dAdt]
# Info    : Solve[QS_dAdt]
# [ simnibs ]INFO: Info    : N: 653426 - cg icc (null)
# [ simnibs ]INFO: Info    :   0 KSP Residual norm 8.157081893388e+01
# [ simnibs ]INFO: Info    :   1 KSP Residual norm 2.998705743945e+01
# [ simnibs ]INFO: Info    :   2 KSP Residual norm 2.752415308274e+01
# [ simnibs ]INFO: Info    :   3 KSP Residual norm 2.392925162862e+01
# [ simnibs ]INFO: Info    :   4 KSP Residual norm 2.135061910454e+01
# [ simnibs ]INFO: Info    :   5 KSP Residual norm 2.000522383617e+01
# [ simnibs ]INFO: Info    :   6 KSP Residual norm 1.877755477756e+01
# [ simnibs ]INFO: Info    :   7 KSP Residual norm 1.685838539119e+01
# [ simnibs ]INFO: Info    :   8 KSP Residual norm 1.577878079034e+01
# [ simnibs ]INFO: Info    :   9 KSP Residual norm 1.382946192309e+01
# [ simnibs ]INFO: Info    :  10 KSP Residual norm 1.249521774217e+01
# [ simnibs ]INFO: Info    :  11 KSP Residual norm 1.137552816908e+01
# [ simnibs ]INFO: Info    :  12 KSP Residual norm 1.015339532654e+01
# [ simnibs ]INFO: Info    :  13 KSP Residual norm 9.193409028966e+00
# [ simnibs ]INFO: Info    :  14 KSP Residual norm 8.281452710004e+00
# [ simnibs ]INFO: Info    :  15 KSP Residual norm 7.284569502165e+00
# [ simnibs ]INFO: Info    :  16 KSP Residual norm 6.388890997724e+00
# [ simnibs ]INFO: Info    :  17 KSP Residual norm 5.505099115575e+00
# [ simnibs ]INFO: Info    :  18 KSP Residual norm 4.767484870022e+00
# [ simnibs ]INFO: Info    :  19 KSP Residual norm 4.277934675300e+00
# [ simnibs ]INFO: Info    :  20 KSP Residual norm 3.603695977045e+00
# [ simnibs ]INFO: Info    :  21 KSP Residual norm 3.058429060446e+00
# [ simnibs ]INFO: Info    :  22 KSP Residual norm 2.652668652011e+00
# [ simnibs ]INFO: Info    :  23 KSP Residual norm 2.270821006296e+00
# [ simnibs ]INFO: Info    :  24 KSP Residual norm 1.954162049618e+00
# [ simnibs ]INFO: Info    :  25 KSP Residual norm 1.639900401220e+00
# [ simnibs ]INFO: Info    :  26 KSP Residual norm 1.387919919686e+00
# [ simnibs ]INFO: Info    :  27 KSP Residual norm 1.198140058569e+00
# [ simnibs ]INFO: Info    :  28 KSP Residual norm 1.011796279742e+00
# [ simnibs ]INFO: Info    :  29 KSP Residual norm 8.194882896626e-01
# [ simnibs ]INFO: Info    :  30 KSP Residual norm 6.911084981250e-01
# [ simnibs ]INFO: Info    :  31 KSP Residual norm 5.794792076183e-01
# [ simnibs ]INFO: Info    :  32 KSP Residual norm 4.903349029337e-01
# [ simnibs ]INFO: Info    :  33 KSP Residual norm 4.173775397693e-01
# [ simnibs ]INFO: Info    :  34 KSP Residual norm 3.612374765641e-01
# [ simnibs ]INFO: Info    :  35 KSP Residual norm 3.074212125416e-01
# [ simnibs ]INFO: Info    :  36 KSP Residual norm 2.686731819893e-01
# [ simnibs ]INFO: Info    :  37 KSP Residual norm 2.408010397920e-01
# [ simnibs ]INFO: Info    :  38 KSP Residual norm 2.193192240017e-01
# [ simnibs ]INFO: Info    :  39 KSP Residual norm 2.066486031860e-01
# [ simnibs ]INFO: Info    :  40 KSP Residual norm 1.914876670855e-01
# [ simnibs ]INFO: Info    :  41 KSP Residual norm 1.799378774794e-01
# [ simnibs ]INFO: Info    :  42 KSP Residual norm 1.797034730903e-01
# [ simnibs ]INFO: Info    :  43 KSP Residual norm 1.755326713186e-01
# [ simnibs ]INFO: Info    :  44 KSP Residual norm 1.650011811148e-01
# [ simnibs ]INFO: Info    :  45 KSP Residual norm 1.463737141127e-01
# [ simnibs ]INFO: Info    :  46 KSP Residual norm 1.226798739451e-01
# [ simnibs ]INFO: Info    :  47 KSP Residual norm 1.072823849715e-01
# [ simnibs ]INFO: Info    :  48 KSP Residual norm 9.659176659984e-02
# [ simnibs ]INFO: Info    :  49 KSP Residual norm 8.738887293371e-02
# [ simnibs ]INFO: Info    :  50 KSP Residual norm 7.829497163874e-02
# [ simnibs ]INFO: Info    :  51 KSP Residual norm 6.777163480660e-02
# [ simnibs ]INFO: Info    :  52 KSP Residual norm 5.728073421936e-02
# [ simnibs ]INFO: Info    :  53 KSP Residual norm 4.654526313676e-02
# [ simnibs ]INFO: Info    :  54 KSP Residual norm 3.657207322448e-02
# [ simnibs ]INFO: Info    :  55 KSP Residual norm 2.983797993229e-02
# [ simnibs ]INFO: Info    :  56 KSP Residual norm 2.474087181814e-02
# [ simnibs ]INFO: Info    :  57 KSP Residual norm 2.014747554222e-02
# [ simnibs ]INFO: Info    :  58 KSP Residual norm 1.655609646101e-02
# [ simnibs ]INFO: Info    :  59 KSP Residual norm 1.413893169439e-02
# [ simnibs ]INFO: Info    :  60 KSP Residual norm 1.252536154742e-02
# [ simnibs ]INFO: Info    :  61 KSP Residual norm 1.119484076546e-02
# [ simnibs ]INFO: Info    :  62 KSP Residual norm 1.047882748902e-02
# [ simnibs ]INFO: Info    :  63 KSP Residual norm 1.008804702865e-02
# [ simnibs ]INFO: Info    :  64 KSP Residual norm 9.594592938666e-03
# [ simnibs ]INFO: Info    :  65 KSP Residual norm 8.887892866848e-03
# [ simnibs ]INFO: Info    :  66 KSP Residual norm 8.059303761119e-03
# [ simnibs ]INFO: Info    :  67 KSP Residual norm 7.157955277633e-03
# [ simnibs ]INFO: Info    :  68 KSP Residual norm 6.344057236961e-03
# [ simnibs ]INFO: Info    :  69 KSP Residual norm 5.477577096652e-03
# [ simnibs ]INFO: Info    :  70 KSP Residual norm 4.698184827632e-03
# [ simnibs ]INFO: Info    :  71 KSP Residual norm 3.954742061419e-03
# [ simnibs ]INFO: Info    :  72 KSP Residual norm 3.378270046770e-03
# [ simnibs ]INFO: Info    :  73 KSP Residual norm 3.050266471171e-03
# [ simnibs ]INFO: Info    :  74 KSP Residual norm 2.801849167261e-03
# [ simnibs ]INFO: Info    :  75 KSP Residual norm 2.462212567774e-03
# [ simnibs ]INFO: Info    :  76 KSP Residual norm 2.097619015479e-03
# [ simnibs ]INFO: Info    :  77 KSP Residual norm 1.786298423718e-03
# [ simnibs ]INFO: Info    :  78 KSP Residual norm 1.566039511245e-03
# [ simnibs ]INFO: Info    :  79 KSP Residual norm 1.317902912382e-03
# [ simnibs ]INFO: Info    :  80 KSP Residual norm 1.093895047793e-03
# [ simnibs ]INFO: Info    :  81 KSP Residual norm 9.013261422087e-04
# [ simnibs ]INFO: Info    :  82 KSP Residual norm 7.222371508155e-04
# [ simnibs ]INFO: Info    :  83 KSP Residual norm 5.922001491581e-04
# [ simnibs ]INFO: Info    :  84 KSP Residual norm 4.961829291108e-04
# [ simnibs ]INFO: Info    :  85 KSP Residual norm 4.099243431918e-04
# [ simnibs ]INFO: Info    :  86 KSP Residual norm 3.295244892334e-04
# [ simnibs ]INFO: Info    :  87 KSP Residual norm 2.746011002342e-04
# [ simnibs ]INFO: Info    :  88 KSP Residual norm 2.339880148403e-04
# [ simnibs ]INFO: Info    :  89 KSP Residual norm 1.996680515144e-04
# [ simnibs ]INFO: Info    :  90 KSP Residual norm 1.663952099563e-04
# [ simnibs ]INFO: Info    :  91 KSP Residual norm 1.414329454015e-04
# [ simnibs ]INFO: Info    :  92 KSP Residual norm 1.215874493000e-04
# [ simnibs ]INFO: Info    :  93 KSP Residual norm 1.010798334709e-04
# [ simnibs ]INFO: Info    :  94 KSP Residual norm 8.090734991542e-05
# [ simnibs ]INFO: Info    :  95 KSP Residual norm 6.325273595839e-05
# [ simnibs ]INFO: Info    :  96 KSP Residual norm 5.164568588503e-05
# [ simnibs ]INFO: Info    :  97 KSP Residual norm 4.312403298190e-05
# [ simnibs ]INFO: Info    :  98 KSP Residual norm 3.580367300357e-05
# [ simnibs ]INFO: Info    :  99 KSP Residual norm 2.958218077547e-05
# [ simnibs ]INFO: Info    : 100 KSP Residual norm 2.453693537142e-05
# [ simnibs ]INFO: Info    : 101 KSP Residual norm 2.047328098265e-05
# [ simnibs ]INFO: Info    : 102 KSP Residual norm 1.730054586086e-05
# [ simnibs ]INFO: Info    : 103 KSP Residual norm 1.460615797438e-05
# [ simnibs ]INFO: Info    : 104 KSP Residual norm 1.164172995133e-05
# [ simnibs ]INFO: Info    : 105 KSP Residual norm 9.256441299325e-06
# [ simnibs ]INFO: Info    : 106 KSP Residual norm 7.083293110348e-06
# [ simnibs ]INFO: Info    : 107 KSP Residual norm 5.441069998452e-06
# [ simnibs ]INFO: Info    : 108 KSP Residual norm 4.069071379541e-06
# [ simnibs ]INFO: Info    : 109 KSP Residual norm 2.981354175010e-06
# [ simnibs ]INFO: Info    : 110 KSP Residual norm 2.289279360143e-06
# [ simnibs ]INFO: Info    : 111 KSP Residual norm 1.767609406636e-06
# [ simnibs ]INFO: Info    : 112 KSP Residual norm 1.336692505052e-06
# [ simnibs ]INFO: Info    : 113 KSP Residual norm 1.063739830978e-06
# [ simnibs ]INFO: Info    : 114 KSP Residual norm 8.686850723260e-07
# [ simnibs ]INFO: Info    : 115 KSP Residual norm 7.177998304881e-07
# [ simnibs ]INFO: Info    : 116 KSP Residual norm 5.857400494622e-07
# [ simnibs ]INFO: Info    : 117 KSP Residual norm 4.946916388978e-07
# [ simnibs ]INFO: Info    : 118 KSP Residual norm 4.199133726677e-07
# [ simnibs ]INFO: Info    : 119 KSP Residual norm 3.517770582079e-07
# [ simnibs ]INFO: Info    : 120 KSP Residual norm 2.997350457831e-07
# [ simnibs ]INFO: Info    : 121 KSP Residual norm 2.484808883277e-07
# [ simnibs ]INFO: Info    : 122 KSP Residual norm 1.946237877599e-07
# [ simnibs ]INFO: Info    : 123 KSP Residual norm 1.502913406522e-07
# [ simnibs ]INFO: Info    : 124 KSP Residual norm 1.151415044392e-07
# [ simnibs ]INFO: Info    : 125 KSP Residual norm 8.927214487929e-08
# [ simnibs ]INFO: Info    : 126 KSP Residual norm 7.069063037225e-08
# [ simnibs ]INFO: Info    : 127 KSP Residual norm 5.699538421404e-08
# [ simnibs ]INFO: Info    : 128 KSP Residual norm 4.701255364116e-08
# [ simnibs ]INFO: Info    : 129 KSP Residual norm 3.770888351463e-08
# [ simnibs ]INFO: Info    : 130 KSP Residual norm 2.959546842023e-08
# [ simnibs ]INFO: Info    : 131 KSP Residual norm 2.268139778227e-08
# [ simnibs ]INFO: Info    : 132 KSP Residual norm 1.615514828341e-08
# [ simnibs ]INFO: Info    : 133 KSP Residual norm 1.162786352889e-08
# [ simnibs ]INFO: Info    : 134 KSP Residual norm 8.917159683394e-09
# [ simnibs ]INFO: Info    : 135 KSP Residual norm 7.288363093518e-09
# [ simnibs ]INFO: Info    : 135 iterations
# [ simnibs ]INFO: Info    : SaveSolution[QS_dAdt]
# [ simnibs ]INFO: Info    : (Wall = 217.086s, CPU = 240.145s, Mem = 4110.69Mb)
# [ simnibs ]INFO: E n d   P r o c e s s i n g
# [ simnibs ]INFO: Info    : Stopped (Tue Nov 13 11:35:59 2018, Wall = 217.83s, CPU = 240.619s, Mem = 4110.69Mb)
# [ simnibs ]INFO: Execution finished
# [ simnibs ]WARNING: /Users/stadayon/anaconda2/envs/pynetstim/lib/python2.7/site-packages/simnibs/msh/gmsh_numpy.py:3241: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   cols = np.fromstring(s[0:-1], dtype=np.float)
#
# [ simnibs ]INFO: Finished Running Poslist Number: 1
# [ simnibs ]INFO: Result Files:
# /Users/stadayon/Dropbox/projects/broad/data/simnibs_simulations/Broad_63_LG/simnibs_simulations/targets_M1_LDLPFC2/Broad_63_LG_TMS_1-0001_MagVenture_MC_B70_scalar.msh
# /Users/stadayon/Dropbox/projects/broad/data/simnibs_simulations/Broad_63_LG/simnibs_simulations/targets_M1_LDLPFC2/Broad_63_LG_TMS_1-0002_MagVenture_MC_B70_scalar.msh
# [ simnibs ]INFO: Interpolating to the middle of Gray Matter
# [ simnibs ]INFO: Mapping to volume
# [ simnibs ]WARNING: /Users/stadayon/anaconda2/envs/pynetstim/lib/python2.7/site-packages/simnibs/msh/transformations.py:374: UserWarning: Could not find reference volume in mni space at: /Users/stadayon/anaconda2/envs/pynetstim/lib/resources/templates/MNI152_T1_1mm.nii.gz
#   ref_mni))
#
# [ simnibs ]INFO: Field: E
# [ simnibs ]INFO: To file: /Users/stadayon/Dropbox/projects/broad/data/simnibs_simulations/Broad_63_LG/simnibs_simulations/targets_M1_LDLPFC2/subject_volumes/Broad_63_LG_TMS_1-0001_MagVenture_MC_B70_scalar_E.nii.gz
# [ simnibs ]INFO: Field: normE
# [ simnibs ]INFO: To file: /Users/stadayon/Dropbox/projects/broad/data/simnibs_simulations/Broad_63_LG/simnibs_simulations/targets_M1_LDLPFC2/subject_volumes/Broad_63_LG_TMS_1-0001_MagVenture_MC_B70_scalar_normE.nii.gz
# [ simnibs ]INFO: Field: E
# [ simnibs ]INFO: To file: /Users/stadayon/Dropbox/projects/broad/data/simnibs_simulations/Broad_63_LG/simnibs_simulations/targets_M1_LDLPFC2/subject_volumes/Broad_63_LG_TMS_1-0002_MagVenture_MC_B70_scalar_E.nii.gz
# [ simnibs ]INFO: Field: normE
# [ simnibs ]INFO: To file: /Users/stadayon/Dropbox/projects/broad/data/simnibs_simulations/Broad_63_LG/simnibs_simulations/targets_M1_LDLPFC2/subject_volumes/Broad_63_LG_TMS_1-0002_MagVenture_MC_B70_scalar_normE.nii.gz
# [ simnibs ]INFO: =====================================
# [ simnibs ]INFO: SimNIBS finished running simulations
# [ simnibs ]INFO: Simulation Result Meshed:
# [ simnibs ]INFO: /Users/stadayon/Dropbox/projects/broad/data/simnibs_simulations/Broad_63_LG/simnibs_simulations/targets_M1_LDLPFC2/Broad_63_LG_TMS_1-0001_MagVenture_MC_B70_scalar.msh
# [ simnibs ]INFO: /Users/stadayon/Dropbox/projects/broad/data/simnibs_simulations/Broad_63_LG/simnibs_simulations/targets_M1_LDLPFC2/Broad_63_LG_TMS_1-0002_MagVenture_MC_B70_scalar.msh
# [ simnibs ]INFO: Postprocessing Folders:
# [ simnibs ]INFO: /Users/stadayon/Dropbox/projects/broad/data/simnibs_simulations/Broad_63_LG/simnibs_simulations/targets_M1_LDLPFC2/subject_overlays
# [ simnibs ]INFO: /Users/stadayon/Dropbox/projects/broad/data/simnibs_simulations/Broad_63_LG/simnibs_simulations/targets_M1_LDLPFC2/subject_volumes
# [ simnibs ]INFO: =====================================

# %%
t = 1
brain = Brain(subject_id='fs_'+subject,subjects_dir=simnibs_dir,surf='pial',hemi='both',offset=False)
sim_data = nib.freesurfer.read_morph_data('/Users/stadayon/Dropbox/projects/broad/data/simnibs_simulations/{subject}/simnibs_simulations/targets_M1_LDLPFC2/subject_overlays/lh.{subject}_TMS_1-000{t}_MagVenture_MC_B70_scalar.central.E.norm'.format(subject=subject,t=t+1))
sim_data = sim_data/np.max(sim_data)

# %%
brain.add_overlay(sim_data,hemi='lh',min=0,max=1)
brain.add_foci(s.targets.coordinates['ras_tkr_coord'][t,:],hemi=s.targets.hemi[t])
mlab.show()
